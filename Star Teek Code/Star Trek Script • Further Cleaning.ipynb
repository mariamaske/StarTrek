# %% [markdown]
# # Star Trek Script • Further Cleaning

# %% [markdown]
# ## Importing libaries

# %%
#import libraries
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from operator import itemgetter
from collections import defaultdict
import os

# %%
# Assign path variable
path = '/Users/mariamaske/Star Trek Analysis/Data/Cleaned Data'

# %%
# Import tos data
tos_df = pd.read_csv(os.path.join(path, 'tos_df.csv'))

# %%
# Import tas data
tas_df = pd.read_csv(os.path.join(path, 'tas_df.csv'))

# %%
# Import tng data
tng_df = pd.read_csv(os.path.join(path, 'tng_df.csv'))

# %%
# Import tng data
tng_df = pd.read_csv(os.path.join(path, 'tng_df.csv'))

# %%
# Import ds9 data
ds9_df = pd.read_csv(os.path.join(path, 'ds9_df.csv'))

# %%
# Import voy data
voy_df = pd.read_csv(os.path.join(path, 'voy_df.csv'))

# %%
# Import ent data
ent_df = pd.read_csv(os.path.join(path, 'ent_df.csv'))

# %%
# Import dis data
dis_df = pd.read_csv(os.path.join(path, 'dis_df.csv'))

# %%
# Import dis data
pic_df = pd.read_csv(os.path.join(path, 'pic_df.csv'))

# %% [markdown]
# ## Further Cleaning

# %% [markdown]
# ### TOS

# %%
tos_df.head()
# Out:
#    Unnamed: 0  Episode Character  \
# 0           0  tos_000     SPOCK
# 1           1  tos_001     SPOCK
# 2           2  tos_002     SPOCK
# 3           3  tos_003     SPOCK
# 4           4  tos_004     SPOCK
#
#                                                Lines  Linecount  Season  Year  \
# 0  ['Check the circuit.', "It can't be the screen...         27  tos_s1  1966
# 1  ['Miss Uhura, your last sub-space log containe...         46  tos_s1  1966
# 2  ['That is a very intriguing question. Scanners...         33  tos_s1  1966
# 3  ['Your move, Captain.', "I'll have you checkma...         40  tos_s1  1966
# 4  ['Check out the life-support systems.', 'Someo...         80  tos_s1  1966
#
#                           Title Gender       Spezies Frequency of appearance  \
# 0                      The Cage      m  Vulcan/Human                Maincast
# 1                  The Man Trap      m  Vulcan/Human                Maincast
# ...

# %%
tos_df['Series'] = "The Original Series (TOS)"

# %%
# renames columns to make them more conform with the other data sets 
tos_df.rename(columns = {'Admirality' : 'Admirality?'}, inplace = True)

# %%
tos_df= tos_df.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# ### TAS

# %%
tas_df.head()
# Out:
#    Unnamed: 0  Episode Character  \
# 0           0  tas_000      KIRK
# 1           1  tas_001      KIRK
# 2           2  tas_002      KIRK
# 3           3  tas_003      KIRK
# 4           4  tas_004      KIRK
#
#                                                Lines  Linecount  Season  Year  \
# 0  ['Situation, Mister Scott?', 'Mister Sulu?', '...         68  tas_s1  1973
# 1  ["What a trip, Bones. Orion, at the dawn of it...         25  tas_s1  1973
# 2  ['Readings?', 'Put up our present position, Li...         78  tas_s1  1973
# 3  ["Twenty seconds to what? That's what worries ...         34  tas_s1  1973
# 4  ["Klingon battle cruiser, identify yourself. A...         73  tas_s1  1973
#
#                            Title Gender Spezies Frequency of appearance  Role  \
# 0       Beyond The Farthest Star      m   Human                Maincast  Crew
# 1                     Yesteryear      m   Human                Maincast  Crew
# ...

# %%
tas_df['Series'] = "The Animated Series (TAS)"

# %%
# renames columns to make them more conform with the other data sets 
tas_df.rename(columns = {'Admirality' : 'Admirality?'}, inplace = True)

# %%
tas_df= tas_df.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# ### TNG

# %%
tng_df.head()
# Out:
#    Unnamed: 0  Episode Character  \
# 0           0  tng_000    PICARD
# 1           1  tng_001    PICARD
# 2           2  tng_002    PICARD
# 3           3  tng_003    PICARD
# 4           4  tng_004    PICARD
#
#                                                Lines  Linecount  Season  Year  \
# 0  ["You will agree, Data, that Starfleet's\r ord...        184  tng_s1  1987
# 1  ['Report.', 'Are you certain? Yes, of course y...         83  tng_s1  1987
# 2  ['On our way. You have the helm, Mister Data.'...         93  tng_s1  1987
# 3  ['Enlarge. What is their course?', 'Identify.'...         99  tng_s1  1987
# 4  ["I don't understand your concern, Number\r On...        112  tng_s1  1987
#
#                           Title Gender Spezies Frequency of appearance  Role  \
# 0         Encounter at Farpoint      m   Human                Maincast  Crew
# 1                 The Naked Now      m   Human                Maincast  Crew
# ...

# %%
tng_df['Series'] = "The Next Generation (TNG)"

# %%
tng_df= tng_df.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# ### DS9

# %%
ds9_df.head()
# Out:
#    Unnamed: 0  Episode Character  \
# 0           0  ds9_000     SISKO
# 1           1  ds9_001     SISKO
# 2           2  ds9_002     SISKO
# 3           3  ds9_003     SISKO
# 4           4  ds9_004     SISKO
#
#                                                Lines  Linecount  Season  Year  \
# 0  ['Reroute auxiliary power.', 'Full reverse.', ...        189  ds9_s1  1993
# 1  ["We don't know for a fact Garak's a spy, Doct...         88  ds9_s1  1993
# 2  ['Ready, Dax?', 'Doctor.', 'Well, some things ...         58  ds9_s1  1993
# 3  ['Chief, I thought you were going to fix the r...         76  ds9_s1  1993
# 4  ["Miss Sarda, why don't tell me exactly what h...         65  ds9_s1  1993
#
#                        Title Gender Spezies  Role Frequency of appearance  \
# 0  Emissary (2-part episode)      m   Human  Crew                Maincast
# 1              Past Prologue      m   Human  Crew                Maincast
# ...

# %%
ds9_df['Series'] = "Deep Space Nine (DS9)"

# %%
ds9_df= ds9_df.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# ### VOY

# %%
voy_df.head()
# Out:
#    Unnamed: 0  Episode Character  \
# 0           0  voy_000  CHAKOTAY
# 1           1  voy_001  CHAKOTAY
# 2           2  voy_002  CHAKOTAY
# 3           3  voy_003  CHAKOTAY
# 4           4  voy_004  CHAKOTAY
#
#                                                Lines  Linecount  Season  Year  \
# 0  ['Damage report.', 'Be creative!', 'Initiating...         45  voy_s1  1995
# 1  ['Then what happened?', "Don't worry, Lieutena...         64  voy_s1  1995
# 2  ['Density patterns on the surface show artific...         29  voy_s1  1995
# 3  ['Lieutenant Torres has already asked permissi...         41  voy_s1  1995
# 4  ['Bridge to Janeway.', 'There was no need for ...         37  voy_s1  1995
#
#                     Title Gender Spezies Frequency of appearance  Role  \
# 0  Caretaker, Part I & II      m   Human                Maincast  Crew
# 1                Parallax      m   Human                Maincast  Crew
# 2          Time and Again      m   Human                Maincast  Crew
# ...

# %%
voy_df['Series'] = "Star Trek Voyager (VOY)"

# %%
voy_df= voy_df.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# ### ENT

# %%
ent_df.head()
# Out:
#    Unnamed: 0  Episode Character  \
# 0           0  ent_000    KLAANG
# 1           1  ent_000    TUCKER
# 2           2  ent_001    TUCKER
# 3           3  ent_002    TUCKER
# 4           4  ent_003    TUCKER
#
#                                                Lines  Linecount  Season  Year  \
# 0  ['', '', 'Pung ghap! Pung ghap!', 'DujDaj Hegh...         22  ent_s1  2001
# 1  ["The ventral plating team says they'll be don...         98  ent_s1  2001
# 2  ["We've routed some more power to Sickbay. Let...         41  ent_s1  2001
# 3  ['Sounds like home.', 'You expect us to sit up...        118  ent_s1  2001
# 4  ["Well, tell him to hurry up. If the relays up...        133  ent_s1  2001
#
#                Title Gender  Spezies Frequency of appearance   Role  \
# 0         Broken Bow      m  Klingon                Episodic  Alien
# 1         Broken Bow      m    Human                Maincast   Crew
# 2    Fight or Flight      m    Human                Maincast   Crew
# ...

# %%
ent_df['Series'] = "Star Trek Enterprise (ENT)"

# %%
ent_df= ent_df.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# ### DIS

# %%
dis_df.head()
# Out:
#    Unnamed: 0  Episode Character  \
# 0           0  dis_000   T'KUVMA
# 1           1  dis_001   T'KUVMA
# 2           2  dis_000   BURNHAM
# 3           3  dis_001   BURNHAM
# 4           4  dis_002   BURNHAM
#
#                                                Lines  Linecount  Season  Year  \
# 0  ['They are coming. Atom by atom they will coil...         12  dis_s1  2017
# 1  ['My presence. My voyage. My time. No one spea...         26  dis_s1  2017
# 2  ["We come in peace. That's why we're here. Isn...        113  dis_s1  2017
# 3  ['Respect is earned, as is friendliness.', 'Th...         41  dis_s1  2017
# 4  ['Eight thousand, one hundred and eighty six.'...         83  dis_s1  2017
#
#                         Title Gender  Spezies Frequency of appearance  \
# 0            The Vulcan Hello      m  Klingon              Recrurring
# 1  Battle at the Binary Stars      m  Klingon              Recrurring
# 2            The Vulcan Hello      f    Human                Maincast
# ...

# %%
dis_df['Series'] = "Star Trek Discovery (DIS)"

# %%
dis_df= dis_df.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# ### PIC

# %%
pic_df.head()
# Out:
#    Unnamed: 0  Episode Character  \
# 0           0  pic_000    PICARD
# 1           1  pic_001    PICARD
# 2           2  pic_002    PICARD
# 3           3  pic_003    PICARD
# 4           4  pic_004    PICARD
#
#                                                Lines  Linecount  Season  Year  \
# 0  ['See. And raise.', 'You have a tell.', "Every...        129  pic_s1  2020
# 1  ['They erased her.', 'Then who?', 'What is Zha...         70  pic_s1  2020
# 2  ['Straight out, just as you predicted.', 'Mmm ...         73  pic_s1  2020
# 3  ["Hello, hello. How good to see you all again....         94  pic_s1  2020
# 4  ['Come.', "You're well?", 'Something to drink?...         59  pic_s1  2020
#
#                       Title Gender Spezies Frequency of appearance  Role  \
# 0               Remembrance      m   Human                Maincast  Crew
# 1          Maps and Legends      m   Human                Maincast  Crew
# ...

# %%
pic_df['Series'] = "Star Trek Picard (PIC)"

# %%
pic_df= pic_df.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# ### Merging Datasets

# %%
concat_ST_final=pd.concat([tos_df, tas_df, tng_df, ds9_df, voy_df, ent_df, dis_df, pic_df])

# %%
concat_ST_final.isnull().sum()
# Out:
# Episode                       0
# Character                     0
# Lines                         0
# Linecount                     0
# Season                        0
# Year                          0
# Title                         0
# Gender                        0
# Spezies                       0
# Frequency of appearance       0
# Role                          0
# Admirality?                   0
# Series                        0
# _merge                     6272
# dtype: int64

# %%
concat_ST_final.columns
# Out:
# Index(['Episode', 'Character', 'Lines', 'Linecount', 'Season', 'Year', 'Title',
#        'Gender', 'Spezies', 'Frequency of appearance', 'Role', 'Admirality?',
#        'Series', '_merge'],
#       dtype='object')

# %%
concat_ST_final.head(30)
# Out:
#     Episode Character                                              Lines  \
# 0   tos_000     SPOCK  ['Check the circuit.', "It can't be the screen...
# 1   tos_001     SPOCK  ['Miss Uhura, your last sub-space log containe...
# 2   tos_002     SPOCK  ['That is a very intriguing question. Scanners...
# 3   tos_003     SPOCK  ['Your move, Captain.', "I'll have you checkma...
# 4   tos_004     SPOCK  ['Check out the life-support systems.', 'Someo...
# 5   tos_005     SPOCK  ['Mister Spock.', 'Is there something I can do...
# 6   tos_006     SPOCK  ["Difficult to say, Captain. We're getting no ...
# 7   tos_007     SPOCK  ["Ship's record banks show little we don't alr...
# 8   tos_008     SPOCK  ['Not a vessel, a ground source. The third pla...
# 9   tos_009     SPOCK  ['I have them, Captain. Closing off deck fourt...
# 10  tos_010     SPOCK  ['One degree to overlap. Stand by to\r photogr...
# 11  tos_011     SPOCK  ['Eleven years, four months, five days.', "Cap...
# ...

# %%
#drop column
df_final= concat_ST_final.drop(columns = ['_merge'])

# %%
df_final = df_final.drop(columns = ['Lines'])

# %%
df_final.head()
# Out:
#    Episode Character  Linecount  Season  Year                         Title  \
# 0  tos_000     SPOCK         27  tos_s1  1966                      The Cage
# 1  tos_001     SPOCK         46  tos_s1  1966                  The Man Trap
# 2  tos_002     SPOCK         33  tos_s1  1966                     Charlie X
# 3  tos_003     SPOCK         40  tos_s1  1966  Where No Man Has Gone Before
# 4  tos_004     SPOCK         80  tos_s1  1966                The Naked Time
#
#   Gender       Spezies Frequency of appearance  Role Admirality?  \
# 0      m  Vulcan/Human                Maincast  Crew          No
# 1      m  Vulcan/Human                Maincast  Crew          No
# 2      m  Vulcan/Human                Maincast  Crew          No
# 3      m  Vulcan/Human                Maincast  Crew          No
# 4      m  Vulcan/Human                Maincast  Crew          No
#
#                       Series
# 0  The Original Series (TOS)
# 1  The Original Series (TOS)
# ...

# %% [markdown]
# ### Saving new dataset

# %%
# exporting Star trek final data
df_final.to_csv(os.path.join(path,'StarTrek_complete.csv'))
